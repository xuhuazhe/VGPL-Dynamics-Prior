# %%
import h5py
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from PIL import Image
import time

# %%
def plot_curves(iters, loss):
    plt.figure(figsize=[16,9])
    plt.plot(iters, loss)
    plt.xlabel('iterations', fontsize=30)
    plt.ylabel('emd loss', fontsize=30)
    plt.title('Training Loss', fontsize=35)
    plt.xticks(fontsize=25)
    plt.yticks(fontsize=25)
#     plt.plot(loss)

# %%
with open('../dump/dump_Gripper/files_dy23-Sep-2021-22:06:48.382191_nHis4_aug0.05emd_uh_clip_seqlen5_uhw0.1_clipw0.1/train.npy', 'rb') as f:
    train_log = np.load(f, allow_pickle=True)
    train_log = train_log[None][0]

# %%
# %matplotlib inline
# plot_curves(train_log['loss'])
plot_curves(train_log['iters'], train_log['loss'])
# print(train_log['iters'])

# %%
train_log['iters']
# Out:
# [0,
#  100,
#  200,
#  300,
#  400,
#  500,
#  0,
#  507,
#  607,
#  707,
#  807,
#  907,
#  1007,
#  57,
#  1014,
#  1114,
#  1214,
#  1314,
#  1414,
#  1514,
#  114,
#  1521,
#  1621,
#  1721,
#  1821,
#  1921,
#  2021,
#  171,
#  2028,
#  2128,
#  2228,
#  2328,
#  2428,
#  2528,
#  228,
#  2535,
#  2635,
#  2735,
#  2835,
#  2935,
#  3035,
#  285,
#  3042,
#  3142,
#  3242,
#  3342,
#  3442,
#  3542,
#  342,
#  3549,
#  3649,
#  3749,
#  3849,
#  3949,
#  4049,
#  399,
#  4056,
#  4156,
#  4256,
#  4356,
#  4456,
#  4556,
#  456,
#  4563,
#  4663,
#  4763,
#  4863,
#  4963,
#  5063,
#  513,
#  5070,
#  5170,
#  5270,
#  5370,
#  5470,
#  5570,
#  570,
#  5577,
#  5677,
#  5777,
#  5877,
#  5977,
#  6077,
#  627,
#  6084,
#  6184,
#  6284,
#  6384,
#  6484,
#  6584,
#  684,
#  6591,
#  6691,
#  6791,
#  6891,
#  6991,
#  7091,
#  741,
#  7098,
#  7198,
#  7298,
#  7398,
#  7498,
#  7598,
#  798,
#  7605,
#  7705,
#  7805,
#  7905,
#  8005,
#  8105,
#  855,
#  8112,
#  8212,
# ...
